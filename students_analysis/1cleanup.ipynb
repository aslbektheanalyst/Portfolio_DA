# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter


df = pd.read_csv('student_exam_performance.csv')

# %%
df.shape
# Out:
# (100000, 44)

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'education_level', 'school_type',
#        'family_income', 'parent_education', 'urban_rural',
#        'previous_exam_score', 'previous_gpa', 'attendance_percentage',
#        'assignment_completion_rate', 'class_participation',
#        'study_hours_per_day', 'self_study_hours', 'private_tuition',
#        'online_learning_hours', 'study_consistency', 'study_environment',
#        'study_method', 'revision_frequency', 'practice_tests_completed',
#        'notes_quality', 'sleep_hours', 'sleep_quality', 'daily_screen_time',
#        'physical_activity_hours', 'break_frequency', 'stress_level',
#        'motivation_level', 'internet_access', 'device_availability',
#        'educational_app_usage', 'online_course_hours', 'exam_difficulty',
#        'exam_preparation_days', 'questions_attempted', 'questions_correct',
#        'time_management_score', 'exam_anxiety_level', 'exam_score',
# ...

# %%
#removing unnecessary and extreme niche columns for my project

df = df.drop(columns=[
    "urban_rural",
    "attendance_percentage",
    "online_learning_hours",
    "study_method",
    "notes_quality",
    "sleep_quality",
    "break_frequency",
    "motivation_level",
    "educational_app_usage",
    "online_course_hours",
    "device_availability"
])

# %%
df.head(2)
# Out:
#    student_id  age  gender education_level school_type family_income  \
# 0  STU_000001   20  Female     High School      Public        Middle
# 1  STU_000002   17    Male     High School      Public        Middle
#
#   parent_education  previous_exam_score  previous_gpa  \
# 0              NaN                78.36          2.95
# 1              NaN                73.40          2.89
#
#    assignment_completion_rate  ... exam_difficulty  exam_preparation_days  \
# 0                       65.18  ...          Medium                     27
# 1                       76.53  ...            Easy                      4
#
#    questions_attempted  questions_correct time_management_score  \
# 0                   95                 86                   NaN
# 1                  100                 86                 87.17
#
#   exam_anxiety_level exam_score  performance_grade  pass_status  \
# 0               9.39      90.40                  A         Pass
# ...

# %%
#checking impossible values
df.describe()
# Out:
#                  age  previous_exam_score  previous_gpa  \
# count  100000.000000        100000.000000  92207.000000
# mean       17.005740            69.531033      2.780892
# std         1.999562            11.379108      0.478218
# min        14.000000            30.000000      1.000000
# 25%        15.000000            61.820000      2.460000
# 50%        17.000000            69.530000      2.780000
# 75%        19.000000            77.232500      3.110000
# max        20.000000           100.000000      4.000000
#
#        assignment_completion_rate  study_hours_per_day  self_study_hours  \
# count               100000.000000        100000.000000     100000.000000
# mean                    69.724405             2.995725          2.094970
# std                     12.127179             1.719466          1.266066
# min                     20.000000             0.500000          0.250000
# 25%                     61.480000             1.720000          1.170000
# ...

# %%
#checking if incorrect data types
df.dtypes
# Out:
# student_id                        str
# age                             int64
# gender                            str
# education_level                   str
# school_type                       str
# family_income                     str
# parent_education                  str
# previous_exam_score           float64
# previous_gpa                  float64
# assignment_completion_rate    float64
# class_participation               str
# study_hours_per_day           float64
# self_study_hours              float64
# private_tuition                 int64
# study_consistency                 str
# study_environment                 str
# revision_frequency                str
# practice_tests_completed        int64
# sleep_hours                   float64
# daily_screen_time             float64
# physical_activity_hours       float64
# stress_level                    int64
# internet_access                 int64
# exam_difficulty                   str
# exam_preparation_days           int64
# ...

# %%
df.isna().sum()
# Out:
# student_id                       0
# age                              0
# gender                           0
# education_level                  0
# school_type                      0
# family_income                    0
# parent_education              6526
# previous_exam_score              0
# previous_gpa                  7793
# assignment_completion_rate       0
# class_participation              0
# study_hours_per_day              0
# self_study_hours                 0
# private_tuition                  0
# study_consistency                0
# study_environment                0
# revision_frequency               0
# practice_tests_completed         0
# sleep_hours                      0
# daily_screen_time                0
# physical_activity_hours          0
# stress_level                     0
# internet_access                  0
# exam_difficulty                  0
# exam_preparation_days            0
# questions_attempted              0
# questions_correct                0
# ...

# %%
df['student_id'].is_unique
# Out:
# True

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.select_dtypes(include="object").apply(lambda x: x.unique())
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7328\3056900651.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include="object").apply(lambda x: x.unique())
# student_id             [STU_000001, STU_000002, STU_000003, STU_00000...
# gender                                             [Female, Male, Other]
# education_level                             [High School, Undergraduate]
# school_type                                   [Public, Private, Charter]
# family_income            [Middle, High, Lower-Middle, Upper-Middle, Low]
# ...

# %%
df["parent_education"] = df["parent_education"].fillna("Unknown")
df['parent_education'].value_counts()
# Out:
# parent_education
# High School    28122
# Bachelor       27943
# Associate      18640
# Master         14043
# Unknown         6526
# Doctorate       4726
# Name: count, dtype: int64

# %%
#pct of the empy values in these two columns

df[["previous_gpa", "time_management_score"]].isna().mean() * 100
# Out:
# previous_gpa             7.793
# time_management_score    9.613
# dtype: float64

# %%
df["previous_gpa"] = df["previous_gpa"].fillna(df["previous_gpa"].median())

df["time_management_score"] = df["time_management_score"].fillna(
    df["time_management_score"].median()
)

# %%
df.to_csv("cleaned_student_data.csv", index=False)
